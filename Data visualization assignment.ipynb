# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import datasets
import plotly.express as px

# %%
df= pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x =df.iloc[:,0:4]
y= df.iloc[:,4]

# %%
pca = PCA(n_components=3)
transform= pca.fit_transform(x)
new_df = pd.DataFrame(data = transform, columns = ['TD1', 'TD2', 'TD3'])
new_df.head()
# Out:
#         TD1       TD2       TD3
# 0 -2.684126  0.319397 -0.027915
# 1 -2.714142 -0.177001 -0.210464
# 2 -2.888991 -0.144949  0.017900
# 3 -2.745343 -0.318299  0.031559
# 4 -2.728717  0.326755  0.090079

# %%
finaldf = pd.concat([new_df, df[['species']]], axis = 1)

# %%
finaldf
# Out:
#           TD1       TD2       TD3    species
# 0   -2.684126  0.319397 -0.027915     setosa
# 1   -2.714142 -0.177001 -0.210464     setosa
# 2   -2.888991 -0.144949  0.017900     setosa
# 3   -2.745343 -0.318299  0.031559     setosa
# 4   -2.728717  0.326755  0.090079     setosa
# ..        ...       ...       ...        ...
# 145  1.944110  0.187532  0.177825  virginica
# 146  1.527167 -0.375317 -0.121898  virginica
# 147  1.764346  0.078859  0.130482  virginica
# 148  1.900942  0.116628  0.723252  virginica
# 149  1.390189 -0.282661  0.362910  virginica
#
# [150 rows x 4 columns]

# %%
fig = px.scatter_3d(new_df, x='TD1', y='TD2', z='TD3', color=y)
fig.show()
# Out:
# <div>                            <div id="5a7aa5dc-78c9-4550-8d98-05ea4dd5ff5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a7aa5dc-78c9-4550-8d98-05ea4dd5ff5c")) {                    Plotly.newPlot(                        "5a7aa5dc-78c9-4550-8d98-05ea4dd5ff5c",                        [{"hovertemplate": "color=setosa<br>TD1=%{x}<br>TD2=%{y}<br>TD3=%{z}<extra></extra>", "legendgroup": "setosa", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "setosa", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-2.684125625969535, -2.714141687294323, -2.8889905690592954, -2.745342855641408, -2.7287165365545283, -2.280859632844491, -2.8205377507406073, -2.626144973146631, -2.886382731780551, -2.672755797820952, -2.506947090651854, -2.612755230908721, -2.786109266188016, -3.2238037438656497, -2.644750389942028, -2.386039033531131, -2.6235278752244247, -2.6482967062543796, -2.1998203236175784, -2.5879863998787664, -2.3102562152425166, -2.5437052287571547, -3.21593941564861, -2.302733182226205, -2.355754049123771, -2.50666890692582, -2.468820073121337, -2.5623199061960142, -2.6395347153845403, -2.631989387274344, -2.5873984766893505, -2.409932497002173, -2.6488623343499107, -2.5987367491005853, -2.636926878105797, -2.8662416521186675, -2.6252